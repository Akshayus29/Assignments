# %% [markdown]
# ### **1. python practice pdf 1**

# %% [markdown]
# Write a Python program that takes an integer as input and calculates the
# sum of its digits

# %%
num = input("Enter a number: ")

total = 0
for digit in num:
    total += int(digit)

print("Sum of digits:", total)
# Out:
# Enter a number: 29
# Sum of digits: 11

# %% [markdown]
# Create a Python program to calculate the factorial of a given number using
# a function.

# %%
import math
number = 5
factorial = math.factorial(number)
print(factorial)
# Out:
# 120

# %% [markdown]
# Develop a Python program that checks whether a given word or phrase is a
# palindrome.

# %%
text = input("Enter a word or phrase: ")

cleaned = text.replace(" ", "").lower()
if cleaned == cleaned[::-1]:
    print("It is a palindrome")
else:
    print("It is not a palindrome")
# Out:
# Enter a word or phrase: cat
# It is not a palindrome

# %% [markdown]
#  Create a Python program that takes a sentence as input and counts the
# number of vowels and consonants.

# %%
sentence = input("Enter a sentence: ")

vowels = "aeiouAEIOU"
vowel_count = 0
consonant_count = 0

for ch in sentence:
    if ch.isalpha():
        if ch in vowels:
            vowel_count += 1
        else:
            consonant_count += 1

print("Vowels:", vowel_count)
print("Consonants:", consonant_count)
# Out:
# Enter a sentence: hey, look there is a pond
# Vowels: 8
# Consonants: 11

# %% [markdown]
#  Develop a Python program that takes two lists as input and returns a new
# list containing the common elements between them.

# %%
list1 = input("Enter first list (comma separated): ").split(",")
list2 = input("Enter second list (comma separated): ").split(",")

common = []

for item in list1:
    if item in list2:
        common.append(item)

print("Common elements:", common)
# Out:
# Enter first list (comma separated): 12,23,34,45,56,67,78,89
# Enter second list (comma separated): 09,99,12,54,45,76,78
# Common elements: ['12', '45', '78']

# %% [markdown]
#  Write a Python program that takes a string as input and counts the
# frequency of each character in the string.

# %%
text = input("Enter a string: ")

freq = {}

for ch in text:
    if ch in freq:
        freq[ch] += 1
    else:
        freq[ch] = 1

print("Character frequencies:")
for key, value in freq.items():
    print(key, ":", value)
# Out:
# Enter a string: python@123
# Character frequencies:
# p : 1
# y : 1
# t : 1
# h : 1
# o : 1
# n : 1
# @ : 1
# 1 : 1
# 2 : 1
# 3 : 1

# %% [markdown]
#  Develop a Python program that checks if a given year is a leap year.

# %%
year1 = int(input("Enter a year: "))
year2 = int(input("Enter a year: "))

if (year1 % 4 == 0):
    print(year1, "is a leap year")
else:
    print(year1, "is not a leap year")

if (year2 % 4 == 0):
    print(year2, "is a leap year")
else:
    print(year2, "is not a leap year")
# Out:
# Enter a year: 2024
# Enter a year: 2025
# 2024 is a leap year
# 2025 is not a leap year

# %% [markdown]
# Write a Python program that checks if a given number, is a prime number.

# %%
num = int(input("Enter a number: "))

if num < 2:
    print(num, "is not a prime number")
else:
    is_prime = True

    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            is_prime = False
            break

    if is_prime:
        print(num, "is a prime number")
    else:
        print(num, "is not a prime number")
# Out:
# Enter a number: 29
# 29 is a prime number

# %% [markdown]
# Write a Python program to generate the Fibonacci sequence up to a specified number of terms

# %%
n = int(input("Enter number of terms: "))

a, b = 0, 1

for i in range(n):
    print(a)
    a, b = b, a + b
# Out:
# Enter number of terms: 7
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %% [markdown]
#   Write a python program to find the roots of a quadratic equation

# %%
import math

a = float(input("Enter a: "))
b = float(input("Enter b: "))
c = float(input("Enter c: "))

discriminant = b**2 - 4*a*c

if discriminant > 0:
    root1 = (-b + math.sqrt(discriminant)) / (2*a)
    root2 = (-b - math.sqrt(discriminant)) / (2*a)
    print("Two real roots:", root1, "and", root2)

elif discriminant == 0:
    root = -b / (2*a)
    print("One real root:", root)

else:
    real = -b / (2*a)
    imag = math.sqrt(-discriminant) / (2*a)
    print("Complex roots:", f"{real}+{imag}i", "and", f"{real}-{imag}i")
# Out:
# Enter a: 49
# Enter b: 36
# Enter c: 25
# Complex roots: -0.3673469387755102+0.6125849395838218i and -0.3673469387755102-0.6125849395838218i
