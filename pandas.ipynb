# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshayus29/Assignments/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

data = [1,11,14,32,np.nan,189]
print(data)
# Out:
# [1, 11, 14, 32, nan, 189]

# %%
type(data)
# Out:
# list

# %%
myseries = pd.Series(data)
myseries
# Out:
# 0      1.0
# 1     11.0
# 2     14.0
# 3     32.0
# 4      NaN
# 5    189.0
# dtype: float64

# %%
myseries.head(3) #.head fuction and a number gives the value from top to  till the index we given
# Out:
# 0     1.0
# 1    11.0
# 2    14.0
# dtype: float64

# %%
myseries.tail(3) #.tail fuction and a number gives the value from bottom to  till the index we given
# Out:
# 3     32.0
# 4      NaN
# 5    189.0
# dtype: float64

# %%
myseries[2]
# Out:
# np.float64(14.0)

# %%
myseries.iloc[1:3] #iloc (index location) in pandas just like slicing
# Out:
# 1    11.0
# 2    14.0
# dtype: float64

# %%
myseries.loc[1:3] #but in .loc (location) function we can only acess the values which  we apply
# Out:
# 1    11.0
# 2    14.0
# 3    32.0
# dtype: float64

# %%
ser1 = pd.Series([1,2,31,52,11], index = ['A','B','C','D','E',])
ser1
# Out:
# A     1
# B     2
# C    31
# D    52
# E    11
# dtype: int64

# %%
ser1.iloc[1:3]
# Out:
# B     2
# C    31
# dtype: int64

# %% [markdown]
# ### **Dataframe**

# %%
data = {'calories':[420,380,390],'duaration':[30,50,25]}
data
# Out:
# {'calories': [420, 380, 390], 'duaration': [30, 50, 25]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    calories  duaration
# 0       420         30
# 1       380         50
# 2       390         25

# %%
df.loc[0]
# Out:
# calories     420
# duaration     30
# Name: 0, dtype: int64

# %%
df.loc[[0,2]] #we can acess that index position rows
# Out:
#    calories  duaration
# 0       420         30
# 2       390         25

# %%
df.loc[0:2] #We can each rows in this way
# Out:
#    calories  duaration
# 0       420         30
# 1       380         50
# 2       390         25

# %%
student_data = {
    'student_id':[101,102,103,104,105],
    'Name':['Anjith','Abhishek','Priya','Karan','Lali'],
    'Age':[21,23,22,21,23],
    'Department':['CSE','ECE','CSE','ECE','CSE'],
    'CGPA':[3.5,4.2,3.9,3.7,4.1],
    'Year':[2020,2021,2022,2020,2021]
}
student_data
# Out:
# {'student_id': [101, 102, 103, 104, 105],
#  'Name': ['Anjith', 'Abhishek', 'Priya', 'Karan', 'Lali'],
#  'Age': [21, 23, 22, 21, 23],
#  'Department': ['CSE', 'ECE', 'CSE', 'ECE', 'CSE'],
#  'CGPA': [3.5, 4.2, 3.9, 3.7, 4.1],
#  'Year': [2020, 2021, 2022, 2020, 2021]}

# %%
sd = pd.DataFrame(student_data)
sd
# Out:
#    student_id      Name  Age Department  CGPA  Year
# 0         101    Anjith   21        CSE   3.5  2020
# 1         102  Abhishek   23        ECE   4.2  2021
# 2         103     Priya   22        CSE   3.9  2022
# 3         104     Karan   21        ECE   3.7  2020
# 4         105      Lali   23        CSE   4.1  2021

# %%
sd.loc[[0,4]]
# Out:
#    student_id    Name  Age Department  CGPA  Year
# 0         101  Anjith   21        CSE   3.5  2020
# 4         105    Lali   23        CSE   4.1  2021

# %%
sd['Name'] #we access each columns in this way
# Out:
# 0      Anjith
# 1    Abhishek
# 2       Priya
# 3       Karan
# 4        Lali
# Name: Name, dtype: object

# %%
sd.loc[1:3,'Name']
# Out:
# 1    Abhishek
# 2       Priya
# 3       Karan
# Name: Name, dtype: object

# %%
sd.columns #we can see the columns headings in easy way
# Out:
# Index(['student_id', 'Name', 'Age', 'Department', 'CGPA', 'Year'], dtype='object')

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  5 non-null      int64
#  1   Name        5 non-null      object
#  2   Age         5 non-null      int64
#  3   Department  5 non-null      object
#  4   CGPA        5 non-null      float64
#  5   Year        5 non-null      int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 372.0+ bytes

# %%
sd.describe()
# Out:
#        student_id   Age      CGPA        Year
# count    5.000000   5.0  5.000000     5.00000
# mean   103.000000  22.0  3.880000  2020.80000
# std      1.581139   1.0  0.286356     0.83666
# min    101.000000  21.0  3.500000  2020.00000
# 25%    102.000000  21.0  3.700000  2020.00000
# 50%    103.000000  22.0  3.900000  2021.00000
# 75%    104.000000  23.0  4.100000  2021.00000
# max    105.000000  23.0  4.200000  2022.00000

# %%
sd.shape
# Out:
# (5, 6)

# %%
sd.size
# Out:
# 30

# %%
len(sd)
# Out:
# 5

# %%
sd[sd['Department']=='CSE',]
# Out:
#    student_id    Name  Age Department  CGPA  Year
# 0         101  Anjith   21        CSE   3.5  2020
# 2         103   Priya   22        CSE   3.9  2022
# 4         105    Lali   23        CSE   4.1  2021

# %%
sd[(sd['Department']=='CSE') & (sd['CGPA']>4)]
# Out:
#    student_id  Name  Age Department  CGPA  Year
# 4         105  Lali   23        CSE   4.1  2021

# %%
sd[(sd['Department']=='CSE') & (sd['CGPA']>4)]['Name']
# Out:
# 4    Lali
# Name: Name, dtype: object

# %%
sd[(sd['Department']=='CSE') & (sd['CGPA']>4)][['Name','CGPA']]
# Out:
#    Name  CGPA
# 4  Lali   4.1

# %%
#nunique(),unique().value_counts()
sd.nunique()
# Out:
# student_id    5
# Name          5
# Age           3
# Department    2
# CGPA          5
# Year          3
# dtype: int64

# %%
sd['Department'].unique() #or sd.Department.unique()
# Out:
# array(['CSE', 'ECE'], dtype=object)

# %%
sd.value_counts()
# Out:
# student_id  Name      Age  Department  CGPA  Year
# 101         Anjith    21   CSE         3.5   2020    1
# 102         Abhishek  23   ECE         4.2   2021    1
# 103         Priya     22   CSE         3.9   2022    1
# 104         Karan     21   ECE         3.7   2020    1
# 105         Lali      23   CSE         4.1   2021    1
# Name: count, dtype: int64

# %%
sorted_sd = sd.sort_values(by='CGPA',ascending=False) # ascending=false means we can acces data as descending order
sorted_sd
# Out:
#    student_id      Name  Age Department  CGPA  Year
# 1         102  Abhishek   23        ECE   4.2  2021
# 4         105      Lali   23        CSE   4.1  2021
# 2         103     Priya   22        CSE   3.9  2022
# 3         104     Karan   21        ECE   3.7  2020
# 0         101    Anjith   21        CSE   3.5  2020

# %%
sd['age_now'] = 2025 - sd['Year'] + sd['Age']
sd
# Out:
#    student_id      Name  Age Department  CGPA  Year  age_now
# 0         101    Anjith   21        CSE   3.5  2020       26
# 1         102  Abhishek   23        ECE   4.2  2021       27
# 2         103     Priya   22        CSE   3.9  2022       25
# 3         104     Karan   21        ECE   3.7  2020       26
# 4         105      Lali   23        CSE   4.1  2021       27

# %%
sd['Status']= sd['CGPA'].apply(lambda x: 'pass' if x>3 else 'fail')
sd
# Out:
#    student_id      Name  Age Department  CGPA  Year  age_now Status
# 0         101    Anjith   21        CSE   3.5  2020       26   pass
# 1         102  Abhishek   23        ECE   4.2  2021       27   pass
# 2         103     Priya   22        CSE   3.9  2022       25   pass
# 3         104     Karan   21        ECE   3.7  2020       26   pass
# 4         105      Lali   23        CSE   4.1  2021       27   pass

# %%
# isna(), isnull()

sd.isna().sum()
# Out:
# student_id    0
# Name          0
# Age           0
# Department    0
# CGPA          0
# Year          0
# age_now       0
# Status        0
# dtype: int64

# %%
sd.drop([1,2]) #we can remove the unwanted rows but dont reflect in original data
# Out:
#    student_id    Name  Age Department  CGPA  Year  age_now Status
# 0         101  Anjith   21        CSE   3.5  2020       26   pass
# 3         104   Karan   21        ECE   3.7  2020       26   pass
# 4         105    Lali   23        CSE   4.1  2021       27   pass

# %%
sd
# Out:
#    student_id      Name  Age Department  CGPA  Year  age_now
# 0         101    Anjith   21        CSE   3.5  2020       26
# 1         102  Abhishek   23        ECE   4.2  2021       27
# 2         103     Priya   22        CSE   3.9  2022       25
# 3         104     Karan   21        ECE   3.7  2020       26
# 4         105      Lali   23        CSE   4.1  2021       27

# %%
sd.drop([1,2],inplace=True) #WE can remove the data from the original data

# %%
sd
# Out:
#    student_id    Name  Age Department  CGPA  Year  age_now Status
# 0         101  Anjith   21        CSE   3.5  2020       26   pass
# 3         104   Karan   21        ECE   3.7  2020       26   pass
# 4         105    Lali   23        CSE   4.1  2021       27   pass

# %%
sd
# Out:
#    student_id    Name  Age Department  CGPA  Year  age_now Status
# 0         101  Anjith   21        CSE   3.5  2020       26   pass
# 3         104   Karan   21        ECE   3.7  2020       26   pass
# 4         105    Lali   23        CSE   4.1  2021       27   pass

# %%
sd #if we want it back go to the begining sd starts and run it then comeback and call it
# Out:
#    student_id      Name  Age Department  CGPA  Year
# 0         101    Anjith   21        CSE   3.5  2020
# 1         102  Abhishek   23        ECE   4.2  2021
# 2         103     Priya   22        CSE   3.9  2022
# 3         104     Karan   21        ECE   3.7  2020
# 4         105      Lali   23        CSE   4.1  2021

# %%
sd
# Out:
#    student_id      Name  Age Department  CGPA  Year  age_now
# 0         101    Anjith   21        CSE   3.5  2020       26
# 1         102  Abhishek   23        ECE   4.2  2021       27
# 2         103     Priya   22        CSE   3.9  2022       25
# 3         104     Karan   21        ECE   3.7  2020       26
# 4         105      Lali   23        CSE   4.1  2021       27

# %%
sd
# Out:
#    student_id      Name  Age Department  CGPA  Year  age_now Status
# 0         101    Anjith   21        CSE   3.5  2020       26   pass
# 1         102  Abhishek   23        ECE   4.2  2021       27   pass
# 2         103     Priya   22        CSE   3.9  2022       25   pass
# 3         104     Karan   21        ECE   3.7  2020       26   pass
# 4         105      Lali   23        CSE   4.1  2021       27   pass
